# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df=pd.read_csv('healthcare-dataset-stroke-data.csv')
df.head()
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21   NaN     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5110 entries, 0 to 5109
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5110 non-null   int64
#  1   gender             5110 non-null   object
#  2   age                5110 non-null   float64
#  3   hypertension       5110 non-null   int64
#  4   heart_disease      5110 non-null   int64
#  5   ever_married       5110 non-null   object
#  6   work_type          5110 non-null   object
#  7   Residence_type     5110 non-null   object
#  8   avg_glucose_level  5110 non-null   float64
#  9   bmi                4909 non-null   float64
#  10  smoking_status     5110 non-null   object
#  11  stroke             5110 non-null   int64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 479.2+ KB

# %%
df.isnull().sum()
# Out:
# id                     0
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# ever_married           0
# work_type              0
# Residence_type         0
# avg_glucose_level      0
# bmi                  201
# smoking_status         0
# stroke                 0
# dtype: int64

# %%
df['bmi'] = df['bmi'].fillna(
    df.groupby('age')['bmi'].transform('mean')
)

# %%
df.describe()
# Out:
#                  id          age  hypertension  heart_disease  \
# count   5110.000000  5110.000000   5110.000000    5110.000000
# mean   36517.829354    43.226614      0.097456       0.054012
# std    21161.721625    22.612647      0.296607       0.226063
# min       67.000000     0.080000      0.000000       0.000000
# 25%    17741.250000    25.000000      0.000000       0.000000
# 50%    36932.000000    45.000000      0.000000       0.000000
# 75%    54682.000000    61.000000      0.000000       0.000000
# max    72940.000000    82.000000      1.000000       1.000000
#
#        avg_glucose_level          bmi       stroke
# count        5110.000000  5110.000000  5110.000000
# mean          106.147677    28.918277     0.048728
# std            45.283560     7.729682     0.215320
# min            55.120000    10.300000     0.000000
# 25%            77.245000    23.700000     0.000000
# 50%            91.885000    28.300000     0.000000
# ...

# %%
df['age'] = df['age'].astype('int64')
df['age'].unique()
# Out:
# array([67, 61, 80, 49, 79, 81, 74, 69, 59, 78, 54, 50, 64, 75, 60, 57, 71,
#        52, 82, 65, 58, 42, 48, 72, 63, 76, 39, 77, 73, 56, 45, 70, 66, 51,
#        43, 68, 47, 53, 38, 55,  1, 46, 32, 14,  3,  8, 37, 40, 35, 20, 44,
#        25, 27, 23, 17, 13,  4, 16, 22, 30, 29, 11, 21, 18, 33, 24, 34, 36,
#         0, 41,  5, 26, 31,  7, 12, 62,  2,  9, 15, 28, 10, 19,  6])

# %%
df[df['age'] == 0].shape
# Out:
# (43, 19)

# %%
plt.figure(figsize=(10,6))  
sns.scatterplot(data=df, x='age', y='avg_glucose_level', hue='stroke')
plt.title('Scatter Plot of Age vs Average Glucose Level')
plt.xlabel('Age')
plt.ylabel('Average Glucose Level')
plt.legend(title='Stroke', loc='upper right')
plt.show()

# %%
df.head()
# Out:
#       id  gender  age  hypertension  heart_disease ever_married  \
# 0   9046    Male   67             0              1          Yes
# 1  51676  Female   61             0              0          Yes
# 2  31112    Male   80             0              1          Yes
# 3  60182  Female   49             0              0          Yes
# 4   1665  Female   79             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level    bmi   smoking_status  \
# 0        Private          Urban             228.69  36.60  formerly smoked
# 1  Self-employed          Rural             202.21  30.19     never smoked
# 2        Private          Rural             105.92  32.50     never smoked
# 3        Private          Urban             171.23  34.40           smokes
# 4  Self-employed          Rural             174.12  24.00     never smoked
#
#    stroke
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
plt.figure(figsize=(10,6))  
sns.barplot(data=df, x='work_type', y='gender')

plt.show()

# %%
plt.figure(figsize=(10,6))
sns.countplot(data=df, x='work_type', hue='stroke')
plt.title('Count of Work Type by Stroke Occurrence')
plt.xlabel('Work Type')
plt.ylabel('Count')
plt.legend(title='Stroke', loc='upper right')
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.countplot(data=df, x='Residence_type', hue='stroke')
plt.title('Count of Residence Type by Stroke Occurrence')
plt.xlabel('Residence Type')
plt.ylabel('Count')
plt.legend(title='Stroke', loc='upper right')
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.boxplot(data=df, x='Residence_type', y='age', hue='stroke')
plt.title('Boxplot of Age by Residence Type and Stroke Occurrence')
plt.xlabel('Residence Type')
plt.ylabel('Age')

plt.legend(title='Stroke', loc='upper right')
plt.show()

# %%
df.isnull().sum()
# Out:
# id                   0
# gender               0
# age                  0
# hypertension         0
# heart_disease        0
# ever_married         0
# work_type            0
# Residence_type       0
# avg_glucose_level    0
# bmi                  0
# smoking_status       0
# stroke               0
# dtype: int64

# %%
df.shape
# Out:
# (5110, 12)

# %%
numerical_cols = df.select_dtypes(include=[np.number]).columns.tolist()
num_cols = len(numerical_cols)
fig, axes = plt.subplots(nrows=(num_cols + 2) // 3, ncols=3, figsize=(18, 4 * ((num_cols + 2) // 3)))

axes = axes.flatten()

for i, col in enumerate(numerical_cols):
    sns.histplot(df[col], kde=True, color='blue', bins=40, ax=axes[i])
    axes[i].set_title(f'Distribution of {col}')
    axes[i].set_xlabel(col)
    axes[i].set_ylabel('Frequency')


for j in range(i + 1, len(axes)):
    fig.delaxes(axes[j])

plt.tight_layout()
plt.show()

# %%
sns.boxplot(y='age', data=df)
# Out:
# <Axes: ylabel='age'>

# %%
df.head()
# Out:
#       id  gender  age  hypertension  heart_disease ever_married  \
# 0   9046    Male   67             0              1          Yes
# 1  51676  Female   61             0              0          Yes
# 2  31112    Male   80             0              1          Yes
# 3  60182  Female   49             0              0          Yes
# 4   1665  Female   79             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level    bmi   smoking_status  \
# 0        Private          Urban             228.69  36.60  formerly smoked
# 1  Self-employed          Rural             202.21  30.19     never smoked
# 2        Private          Rural             105.92  32.50     never smoked
# 3        Private          Urban             171.23  34.40           smokes
# 4  Self-employed          Rural             174.12  24.00     never smoked
#
#    stroke
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
df['ever_married'].value_counts()
# Out:
# ever_married
# Yes    3353
# No     1757
# Name: count, dtype: int64

# %%
df['work_type'].value_counts()
# Out:
# work_type
# Private          2925
# Self-employed     819
# children          687
# Govt_job          657
# Never_worked       22
# Name: count, dtype: int64

# %%
df['Residence_type'].value_counts()
# Out:
# Residence_type
# Urban    2596
# Rural    2514
# Name: count, dtype: int64

# %%
df['smoking_status'].value_counts()
# Out:
# smoking_status
# never smoked       1892
# Unknown            1544
# formerly smoked     885
# smokes              789
# Name: count, dtype: int64

# %%
df['ever_married'] = df['ever_married'].map({'Yes':1, 'No':0})
df['Residence_type'] = df['Residence_type'].map({'Urban':1, 'Rural':0})
df['gender'] = df['gender'].map({'Male': 0, 'Female': 1})

# %%
df = pd.get_dummies(df, columns=['work_type', 'smoking_status'], drop_first=True)

# %%
bool_cols = df.select_dtypes(include=['bool']).columns
df[bool_cols] = df[bool_cols].astype(int)

# %%
df.head()
# Out:
#       id  gender  age  hypertension  heart_disease  ever_married  \
# 0   9046     0.0   67             0              1             1
# 1  51676     1.0   61             0              0             1
# 2  31112     0.0   80             0              1             1
# 3  60182     1.0   49             0              0             1
# 4   1665     1.0   79             1              0             1
#
#    Residence_type  avg_glucose_level    bmi  stroke  work_type_Never_worked  \
# 0               1             228.69  36.60       1                       0
# 1               0             202.21  30.19       1                       0
# 2               0             105.92  32.50       1                       0
# 3               1             171.23  34.40       1                       0
# 4               0             174.12  24.00       1                       0
#
#    work_type_Private  work_type_Self-employed  work_type_children  \
# ...

# %%
df.shape
# Out:
# (5110, 17)

# %%
df.dropna(inplace=True)

# %%
df.shape
# Out:
# (5109, 17)

# %%
dfStandardization =df.copy()
dfMinMaxScaler =df.copy()

# %%
from sklearn.preprocessing import MinMaxScaler,StandardScaler

num_cols = ['age', 'avg_glucose_level', 'bmi']

scaler = StandardScaler()
dfStandardization[num_cols] = scaler.fit_transform(dfStandardization[num_cols])
dfStandardization.head()
# Out:
#       id  gender       age  hypertension  heart_disease  ever_married  \
# 0   9046     0.0  1.050758             0              1             1
# 1  51676     1.0  0.785653             0              0             1
# 2  31112     0.0  1.625151             0              1             1
# 3  60182     1.0  0.255444             0              0             1
# 4   1665     1.0  1.580967             1              0             1
#
#    Residence_type  avg_glucose_level       bmi  stroke  \
# 0               1           2.706450  0.993700       1
# 1               0           2.121652  0.164371       1
# 2               0          -0.004867  0.463240       1
# 3               1           1.437473  0.709063       1
# 4               0           1.501297 -0.636494       1
#
#    work_type_Never_worked  work_type_Private  work_type_Self-employed  \
# 0                       0                  1                        0
# ...

# %%
scaler = MinMaxScaler()
dfMinMaxScaler[num_cols] = scaler.fit_transform(dfMinMaxScaler[num_cols])
dfMinMaxScaler.head()
# Out:
#       id  gender       age  hypertension  heart_disease  ever_married  \
# 0   9046     0.0  0.817073             0              1             1
# 1  51676     1.0  0.743902             0              0             1
# 2  31112     0.0  0.975610             0              1             1
# 3  60182     1.0  0.597561             0              0             1
# 4   1665     1.0  0.963415             1              0             1
#
#    Residence_type  avg_glucose_level       bmi  stroke  \
# 0               1           0.801265  0.301260       1
# 1               0           0.679023  0.227835       1
# 2               0           0.234512  0.254296       1
# 3               1           0.536008  0.276060       1
# 4               0           0.549349  0.156930       1
#
#    work_type_Never_worked  work_type_Private  work_type_Self-employed  \
# 0                       0                  1                        0
# ...

# %% [markdown]
# task 1 : Classification

# %%
x = dfStandardization.drop(['stroke','id'], axis=1)
y = dfStandardization['stroke']

# %%
df['stroke'].value_counts()
# Out:
# stroke
# 0    4860
# 1     249
# Name: count, dtype: int64

# %%
from imblearn.over_sampling import RandomOverSampler
from sklearn.model_selection import train_test_split

ros = RandomOverSampler(random_state=42)
x_train, x_test, y_train, y_test = train_test_split(
    x, y, test_size=0.2, random_state=42, stratify=y
)

x_resampled, y_resampled = ros.fit_resample(x_train, y_train)

print(y_resampled.value_counts())
# Out:
# stroke
# 0    3888
# 1    3888
# Name: count, dtype: int64
# /Applications/main/pyhton/.venv/lib/python3.9/site-packages/sklearn/base.py:484: FutureWarning: `BaseEstimator._check_n_features` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation._check_n_features` instead.
#   warnings.warn(
# /Applications/main/pyhton/.venv/lib/python3.9/site-packages/sklearn/base.py:493: FutureWarning: `BaseEstimator._check_feature_names` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation._check_feature_names` instead.
#   warnings.warn(

# %% [markdown]
# 1st model logisticRegression

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import ConfusionMatrixDisplay, classification_report

lg_model = LogisticRegression(penalty='l1', solver='liblinear', C=0.1, max_iter=1000,random_state=42)
lg_model.fit(x_resampled,y_resampled)

lg_y_pred = lg_model.predict(x_test)

lg_prediction_score = classification_report(lg_y_pred,y_test)

print(lg_prediction_score)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.72      0.99      0.84       711
#            1       0.84      0.14      0.23       311
#
#     accuracy                           0.73      1022
#    macro avg       0.78      0.56      0.53      1022
# weighted avg       0.76      0.73      0.65      1022

# %%
from sklearn.model_selection import GridSearchCV

log_reg = LogisticRegression(
    max_iter=1000,
    random_state=42
)

param_grid = {
    'penalty': ['l1', 'l2'],
    'C': [0.01, 0.1, 1, 10],
    'solver': ['liblinear', 'saga']
}

grid = GridSearchCV(
    estimator=log_reg,
    param_grid=param_grid,
    scoring='roc_auc',
    cv=5,
    n_jobs=-1
)

grid.fit(x_resampled, y_resampled)
# Out:
# GridSearchCV(cv=5, estimator=LogisticRegression(max_iter=1000, random_state=42),
#              n_jobs=-1,
#              param_grid={'C': [0.01, 0.1, 1, 10], 'penalty': ['l1', 'l2'],
#                          'solver': ['liblinear', 'saga']},
#              scoring='roc_auc')

# %%
ConfusionMatrixDisplay.from_predictions(y_test, lg_y_pred, cmap='Blues', normalize='true')
plt.title("Confusion Matrix (Normalized by Probability)")
plt.show()

# %%
from sklearn.svm import SVC


svc = SVC(
    C=1,
    gamma=0.1,
    probability=True,
    random_state=42
)

svc_model.fit(x_resampled,y_resampled)

svc_y_pred = svc_model.predict(x_test)

svc_prediction_score = classification_report(svc_y_pred,y_test)

print(svc_prediction_score)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.71      0.98      0.82       706
#            1       0.70      0.11      0.19       316
#
#     accuracy                           0.71      1022
#    macro avg       0.71      0.54      0.51      1022
# weighted avg       0.71      0.71      0.63      1022

# %%
svc = SVC(probability=True, random_state=42)

param_grid = {
    'kernel': ['rbf'],
    'C': [0.1, 1, 10],
    'gamma': [0.01, 0.1, 1]
}

grid = GridSearchCV(
    svc,
    param_grid,
    scoring='roc_auc',
    cv=5,
    n_jobs=-1
)

grid.fit(x_resampled, y_resampled)
# Out:
# GridSearchCV(cv=5, estimator=SVC(probability=True, random_state=42), n_jobs=-1,
#              param_grid={'C': [0.1, 1, 10], 'gamma': [0.01, 0.1, 1],
#                          'kernel': ['rbf']},
#              scoring='roc_auc')

# %%
ConfusionMatrixDisplay.from_predictions(y_test, svc_y_pred, cmap='Blues', normalize='true')
plt.title("Confusion Matrix (Normalized by Probability)")
plt.show()

# %%
from sklearn.tree import DecisionTreeClassifier



dt = DecisionTreeClassifier(
    criterion='gini',
    max_depth=4,
    min_samples_split=20,
    min_samples_leaf=10,
    max_features='sqrt',
    random_state=42
)


dt.fit(x_resampled, y_resampled)


dt_y_pred = dt.predict(x_test)
dt_prediction_score = classification_report(dt_y_pred,y_test)

print(dt_prediction_score)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.36      0.97      0.52       358
#            1       0.80      0.06      0.11       664
#
#     accuracy                           0.38      1022
#    macro avg       0.58      0.52      0.32      1022
# weighted avg       0.65      0.38      0.26      1022

# %%
ConfusionMatrixDisplay.from_predictions(y_test,dt_y_pred, cmap='Blues', normalize='true')
plt.title("Confusion Matrix (Normalized by Probability)")
plt.show()

# %%
dfStandardization.corr()['bmi'].sort_values(ascending=False)
# Out:
# bmi                               1.000000
# ever_married                      0.343499
# age                               0.335102
# work_type_Private                 0.207689
# avg_glucose_level                 0.172307
# hypertension                      0.164668
# smoking_status_formerly smoked    0.107649
# smoking_status_never smoked       0.105748
# smoking_status_smokes             0.090007
# work_type_Self-employed           0.074401
# heart_disease                     0.042890
# stroke                            0.042277
# gender                            0.025599
# id                                0.001370
# Residence_type                   -0.000688
# work_type_Never_worked           -0.028708
# work_type_children               -0.453909
# Name: bmi, dtype: float64

# %%
xreg = dfMinMaxScaler.drop(['bmi','id','work_type_children','work_type_Never_worked','Residence_type','gender'], axis=1)
yreg = dfMinMaxScaler['bmi']

# %%
x_trainreg, x_testreg, y_trainreg, y_testreg = train_test_split( xreg, yreg, test_size=0.3, random_state=42)

# %%
from sklearn.metrics import mean_absolute_error

y_pred_baseline = np.full_like(y_testreg, y_trainreg.mean())
print(mean_absolute_error(y_testreg, y_pred_baseline))
# Out:
# 0.06761116418384812

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

lr = LinearRegression()
lr.fit(x_trainreg, y_trainreg)

lr_pred = lr.predict(x_testreg)

# Metrics
lr_mae = mean_absolute_error(y_testreg, lr_pred)
lr_mse = mean_squared_error(y_testreg, lr_pred)
lr_rmse = np.sqrt(lr_mse)
lr_r2 = r2_score(y_testreg, lr_pred)

print("\n--- Linear Regression Results ---")
print("MAE:", lr_mae)
print("MSE:", lr_mse)
print("RMSE:", lr_rmse)
print("R² Score:", lr_r2)
# Out:
# --- Linear Regression Results ---
# MAE: 0.0595907762911483
# MSE: 0.006141869466096631
# RMSE: 0.07837008017155929
# R² Score: 0.21048369225875085

# %%
from sklearn.linear_model import Ridge, LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score


ridge_model = Ridge(alpha=0.001, max_iter=10000, random_state=42)


ridge_model.fit(x_trainreg, y_trainreg)


ridge_pred = ridge_model.predict(x_testreg)


ridge_mae = mean_absolute_error(y_testreg, ridge_pred)
ridge_mse = mean_squared_error(y_testreg, ridge_pred)
ridge_rmse = np.sqrt(ridge_mse)
ridge_r2 = r2_score(y_testreg, ridge_pred)

print("Ridge Regression (L2) Results ")
print("MAE:", ridge_mae)
print("MSE:", ridge_mse)
print("RMSE:", ridge_rmse)
print("R² Score:", ridge_r2)


line_model = LinearRegression()
line_model.fit(y_testreg.values.reshape(-1, 1), ridge_pred)

best_fit = line_model.predict(y_testreg.values.reshape(-1, 1))

plt.figure(figsize=(8,6))
plt.scatter(y_testreg, ridge_pred, color='blue', alpha=0.5, label='Predicted vs Actual')
plt.plot(y_testreg, best_fit, color='red', linewidth=2, label='Best Fit Line')
plt.plot(y_testreg, y_testreg, color='green', linestyle='--', label='Perfect Fit Line')
plt.xlabel("Actual BMI")
plt.ylabel("Predicted BMI")
plt.title("Ridge Regression Predictions vs Actual BMI")
plt.legend()


plt.text(0.05, 0.95, f"R² = {ridge_r2:.2f}\nRMSE = {ridge_rmse:.2f}",
         transform=plt.gca().transAxes, fontsize=12, verticalalignment='top')

plt.show()
# Out:
# Ridge Regression (L2) Results
# MAE: 0.05959077558686482
# MSE: 0.006141869096557287
# RMSE: 0.07837007781390348
# R² Score: 0.21048373976176937

# %%
from sklearn.svm import SVR
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
import numpy as np


svr = SVR(kernel='rbf')  

param_grid = {
    'C': [0.1, 1, 10, 100],       
    'epsilon': [0.01, 0.1, 0.5, 1], 
    'gamma': ['scale', 'auto']      
}


grid_svr = GridSearchCV(
    estimator=svr,
    param_grid=param_grid,
    cv=5,             
    scoring='r2',     
    n_jobs=-1
)


grid_svr.fit(x_trainreg, y_trainreg)


print("Best Parameters:", grid_svr.best_params_)
print("Best CV R²:", grid_svr.best_score_)


best_svr = grid_svr.best_estimator_
svr_pred = best_svr.predict(x_testreg)


print("\n--- SVR (Tuned) Results ---")
print("MAE:", mean_absolute_error(y_testreg, svr_pred))
print("MSE:", mean_squared_error(y_testreg, svr_pred))
print("RMSE:", np.sqrt(mean_squared_error(y_testreg, svr_pred)))
print("R² Score:", r2_score(y_testreg, svr_pred))
# Out:
# Best Parameters: {'C': 1, 'epsilon': 0.01, 'gamma': 'auto'}
# Best CV R²: 0.23098178040773773
#
# --- SVR (Tuned) Results ---
# MAE: 0.05472879126586016
# MSE: 0.005738215395880734
# RMSE: 0.07575100920701146
# R² Score: 0.2623720420325082

# %%
line_model = SVR()
line_model.fit(y_testreg.values.reshape(-1, 1),svr_pred)

best_fit = line_model.predict(y_testreg.values.reshape(-1, 1))

plt.figure(figsize=(8,6))
plt.scatter(y_testreg, svr_pred, color='blue', alpha=0.5, label='Predicted vs Actual')
plt.plot(y_testreg, best_fit, color='red', linewidth=2, label='Best Fit Line')
plt.plot(y_testreg, y_testreg, color='green', linestyle='--', label='Perfect Fit Line')
plt.xlabel("Actual BMI")
plt.ylabel("Predicted BMI")
plt.title("Ridge Regression Predictions vs Actual BMI")
plt.legend()


plt.text(0.05, 0.95, f"R² = {r2_score(y_testreg, svr_pred):.2f}\nRMSE = {r2_score(y_testreg, svr_pred):.2f}",
         transform=plt.gca().transAxes, fontsize=12, verticalalignment='top')

plt.show()

# %% [markdown]
# CLUSTERING

# %%
from sklearn.decomposition import PCA

# %%
dfStandardization.columns
# Out:
# Index(['id', 'gender', 'age', 'hypertension', 'heart_disease', 'ever_married',
#        'Residence_type', 'avg_glucose_level', 'bmi', 'stroke',
#        'work_type_Never_worked', 'work_type_Private',
#        'work_type_Self-employed', 'work_type_children',
#        'smoking_status_formerly smoked', 'smoking_status_never smoked',
#        'smoking_status_smokes'],
#       dtype='object')

# %%
pca = PCA(n_components=2)
X_pca = pca.fit_transform(dfStandardization.drop(['id','stroke'], axis=1))
X_pca
# Out:
# array([[ 2.53001214,  1.83488236],
#        [ 1.60599642,  1.63766794],
#        [ 1.4657606 , -0.51646439],
#        ...,
#        [-0.19190198, -0.52766166],
#        [ 0.67946977,  1.23733896],
#        [-0.35431396, -0.29438669]])

# %%
plt.figure(figsize=(6, 5))
plt.scatter(X_pca[:, 0], X_pca[:, 1], alpha=0.6)
plt.title("Data projected on 2 principal components")
plt.xlabel("PC1")
plt.ylabel("PC2")
plt.grid(True)
plt.show()

# %%
from sklearn.metrics import silhouette_score
from sklearn.cluster import KMeans, AgglomerativeClustering


wcss = []
for i in range(1, 11):
    kmeans = KMeans(
        n_clusters=i,
        init='k-means++',
        max_iter=300,
        n_init=10,
        random_state=0
    )
    kmeans.fit(X_pca)
    wcss.append(kmeans.inertia_)

plt.figure(figsize=(6, 5))
plt.plot(range(1, 11), wcss, marker='o')
plt.title("Elbow Method - K-Means")
plt.xlabel("Number of clusters")
plt.ylabel("WCSS")
plt.grid(True)
plt.show()

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

for i in range(2, 6):
    kmeans = KMeans(
        n_clusters=i,
        init='k-means++',
        max_iter=300,
        n_init=60,
        random_state=42
    )

    cluster_labels = kmeans.fit_predict(X_pca)
    silhouette_avg = silhouette_score(X_pca, cluster_labels)

    print(f"For n_clusters = {i}, the average silhouette score is: {silhouette_avg:.4f}")
# Out:
# For n_clusters = 2, the average silhouette score is: 0.4131
# For n_clusters = 3, the average silhouette score is: 0.5128
# For n_clusters = 4, the average silhouette score is: 0.4262
# For n_clusters = 5, the average silhouette score is: 0.3707

# %%
from sklearn.cluster import KMeans
from yellowbrick.cluster import SilhouetteVisualizer
import matplotlib.pyplot as plt

for i in range(2, 7):
    kmeans = KMeans(
        n_clusters=i,
        init='k-means++',
        max_iter=300,
        n_init=60,
        random_state=42
    )

    visualizer = SilhouetteVisualizer(kmeans, colors='yellowbrick')
    visualizer.fit(X_pca)
    visualizer.show()

# %%
optimal_k = 3

kmeans_final = KMeans(n_clusters=optimal_k,max_iter=300,n_init=60, random_state=0)
kmeans_labels = kmeans_final.fit_predict(X_pca)


df['KMeans_Cluster'] = kmeans_labels


kmeans_silhouette = silhouette_score(X_pca, kmeans_labels)
print(f"Silhouette Score for K-Means (k=3): {kmeans_silhouette:.3f}")
# Out:
# Silhouette Score for K-Means (k=3): 0.513

# %%
plt.figure(figsize=(6, 5))
plt.scatter(X_pca[:, 0], X_pca[:, 1], c=kmeans_labels, cmap='viridis', alpha=0.6)
plt.title(f"K-Means Clustering (k={optimal_k})")
plt.xlabel("PC1")
plt.ylabel("PC2")
plt.colorbar(label='Cluster')
plt.grid(True)
plt.show()

# %%
import scipy.cluster.hierarchy as sch
plt.figure(figsize=(8, 5))
dendrogram = sch.dendrogram(sch.linkage(X_pca, method='ward'))
plt.title("Hierarchical Clustering Dendrogram")
plt.xlabel("Samples")
plt.ylabel("Euclidean Distance")
plt.show()

# %%
hier_cluster = AgglomerativeClustering(
    n_clusters=optimal_k,
    metric='euclidean',
    linkage='ward'
)
hier_labels = hier_cluster.fit_predict(X_pca)


df['Hier_Cluster'] = hier_labels

plt.figure(figsize=(6, 5))
plt.scatter(X_pca[:, 0], X_pca[:, 1], c=hier_labels, cmap='plasma', alpha=0.6)
plt.title(f"Hierarchical Clustering (k={optimal_k})")
plt.xlabel("PC1")
plt.ylabel("PC2")
plt.colorbar(label='Cluster')
plt.grid(True)
plt.show()

# %%
print("\nK-Means Cluster Summary (numeric features):")
print(df.groupby('KMeans_Cluster').mean(numeric_only=True))

print("\nHierarchical Cluster Summary (numeric features):")
print(df.groupby('Hier_Cluster').mean(numeric_only=True))
# Out:
# K-Means Cluster Summary (numeric features):
#                           id    gender        age  hypertension  \
# KMeans_Cluster
# 0               36229.956885  0.570236  15.924200      0.000695
# 1               36338.762689  0.609076  52.217815      0.107227
# 2               37849.791667  0.520115  61.145115      0.255747
#
#                 heart_disease  ever_married  Residence_type  \
# KMeans_Cluster
# 0                    0.001391      0.124478        0.502782
# 1                    0.055126      0.855126        0.507227
# 2                    0.158046      0.905172        0.522989
#
#                 avg_glucose_level        bmi    stroke  \
# KMeans_Cluster
# 0                       93.522858  21.997713  0.002086
# 1                       89.135116  31.302174  0.051429
# 2                      204.897213  33.036375  0.133621
#
#                 work_type_Never_worked  work_type_Private  \
# KMeans_Cluster
# 0                             0.013908           0.419332
# ...
